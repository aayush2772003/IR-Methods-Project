# %%
import pandas as pd

# Load the documents
doc_columns = ['ID', 'URL', 'TITLE', 'ABSTRACT']
documents = pd.read_csv('./nfcorpus/raw/doc_dump.txt', sep='\t', names=doc_columns, header=None)

qrel_columns = ['QUERY_ID', 'UNUSED', 'DOC_ID', 'RELEVANCE_LEVEL']
qrels = pd.read_csv('./nfcorpus/merged.qrel', sep='\t', names=qrel_columns, header=None)

# %%
query_columns = ['QUERY_ID', 'QUERY_TEXT']
queries = pd.read_csv('./nfcorpus/train.titles.queries', sep='\t', names=query_columns, header=None)

# Filter qrels to only include train query IDs
train_qrels = qrels[qrels['QUERY_ID'].isin(queries['QUERY_ID'])]
print(len(qrels))

# Check if all query IDs from qrels are present in queries
missing_queries = qrels[~qrels['QUERY_ID'].isin(queries['QUERY_ID'])]
print("Missing query IDs: ", missing_queries['QUERY_ID'].unique())
# print number of missing queries
print("Number of missing queries: ", len(missing_queries))
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# Combine titles and abstracts for better content representation
documents['CONTENT'] = documents['TITLE'] + " " + documents['ABSTRACT']

# Vectorize documents
vectorizer = TfidfVectorizer()
doc_vectors = vectorizer.fit_transform(documents['CONTENT'])

# Vectorize queries
query_vectors = vectorizer.transform(queries['QUERY_TEXT'])

# Create a mapping from document IDs to their vector indices for quick access
doc_id_to_index = pd.Series(data=documents.index, index=documents['ID']).to_dict()

# Initialize lists to hold your training data
X_train = []
Y_train = []

# Iterate over each entry in the relevance judgments
# print number of rows in qrels
print("Number of rows in qrels: ", len(qrels))
# Out:
# 169759
# Missing query IDs:  ['PLAIN-1' 'PLAIN-11' 'PLAIN-22' 'PLAIN-32' 'PLAIN-43' 'PLAIN-55'
#  'PLAIN-67' 'PLAIN-77' 'PLAIN-90' 'PLAIN-101' 'PLAIN-111' 'PLAIN-122'
#  'PLAIN-132' 'PLAIN-142' 'PLAIN-152' 'PLAIN-164' 'PLAIN-174' 'PLAIN-185'
#  'PLAIN-195' 'PLAIN-206' 'PLAIN-216' 'PLAIN-226' 'PLAIN-237' 'PLAIN-247'
#  'PLAIN-258' 'PLAIN-269' 'PLAIN-279' 'PLAIN-290' 'PLAIN-304' 'PLAIN-319'
#  'PLAIN-331' 'PLAIN-343' 'PLAIN-357' 'PLAIN-370' 'PLAIN-382' 'PLAIN-394'
#  'PLAIN-406' 'PLAIN-417' 'PLAIN-428' 'PLAIN-440' 'PLAIN-456' 'PLAIN-467'
#  'PLAIN-477' 'PLAIN-487' 'PLAIN-498' 'PLAIN-508' 'PLAIN-519' 'PLAIN-530'
#  'PLAIN-540' 'PLAIN-550' 'PLAIN-560' 'PLAIN-570' 'PLAIN-582' 'PLAIN-592'
#  'PLAIN-602' 'PLAIN-612' 'PLAIN-622' 'PLAIN-633' 'PLAIN-644' 'PLAIN-656'
#  'PLAIN-670' 'PLAIN-680' 'PLAIN-690' 'PLAIN-700' 'PLAIN-710' 'PLAIN-720'
#  'PLAIN-730' 'PLAIN-740' 'PLAIN-750' 'PLAIN-760' 'PLAIN-770' 'PLAIN-781'
#  'PLAIN-791' 'PLAIN-805' 'PLAIN-816' 'PLAIN-826' 'PLAIN-837' 'PLAIN-848'
#  'PLAIN-859' 'PLAIN-871' 'PLAIN-881' 'PLAIN-891' 'PLAIN-901' 'PLAIN-912'
#  'PLAIN-923' 'PLAIN-933' 'PLAIN-945' 'PLAIN-955' 'PLAIN-965' 'PLAIN-976'
#  'PLAIN-986' 'PLAIN-996' 'PLAIN-1007' 'PLAIN-1017' 'PLAIN-1027'
#  'PLAIN-1038' 'PLAIN-1049' 'PLAIN-1065' 'PLAIN-1077' 'PLAIN-1087'
#  'PLAIN-1097' 'PLAIN-1108' 'PLAIN-1118' 'PLAIN-1129' 'PLAIN-1140'
#  'PLAIN-1150' 'PLAIN-1160' 'PLAIN-1171' 'PLAIN-1181' 'PLAIN-1192'
#  'PLAIN-1202' 'PLAIN-1213' 'PLAIN-1224' 'PLAIN-1235' 'PLAIN-1245'
#  'PLAIN-1261' 'PLAIN-1273' 'PLAIN-1287' 'PLAIN-1298' 'PLAIN-1308'
#  'PLAIN-1319' 'PLAIN-1330' 'PLAIN-1341' 'PLAIN-1352' 'PLAIN-1362'
#  'PLAIN-1373' 'PLAIN-1386' 'PLAIN-1397' 'PLAIN-1408' 'PLAIN-1418'
#  'PLAIN-1428' 'PLAIN-1440' 'PLAIN-1451' 'PLAIN-1462' 'PLAIN-1472'
#  'PLAIN-1484' 'PLAIN-1495' 'PLAIN-1505' 'PLAIN-1515' 'PLAIN-1526'
#  'PLAIN-1536' 'PLAIN-1546' 'PLAIN-1556' 'PLAIN-1567' 'PLAIN-1578'
#  'PLAIN-1589' 'PLAIN-1600' 'PLAIN-1610' 'PLAIN-1620' 'PLAIN-1634'
#  'PLAIN-1644' 'PLAIN-1655' 'PLAIN-1666' 'PLAIN-1678' 'PLAIN-1689'
#  'PLAIN-1699' 'PLAIN-1709' 'PLAIN-1720' 'PLAIN-1730' 'PLAIN-1740'
#  'PLAIN-1750' 'PLAIN-1761' 'PLAIN-1771' 'PLAIN-1783' 'PLAIN-1793'
#  'PLAIN-1804' 'PLAIN-1816' 'PLAIN-1826' 'PLAIN-1836' 'PLAIN-1846'
#  'PLAIN-1856' 'PLAIN-1866' 'PLAIN-1876' 'PLAIN-1886' 'PLAIN-1896'
#  'PLAIN-1907' 'PLAIN-1918' 'PLAIN-1928' 'PLAIN-1939' 'PLAIN-1949'
#  'PLAIN-1961' 'PLAIN-1971' 'PLAIN-1982' 'PLAIN-1994' 'PLAIN-2007'
#  'PLAIN-2018' 'PLAIN-2029' 'PLAIN-2039' 'PLAIN-2050' 'PLAIN-2060'
#  'PLAIN-2070' 'PLAIN-2080' 'PLAIN-2091' 'PLAIN-2101' 'PLAIN-2112'
#  'PLAIN-2123' 'PLAIN-2133' 'PLAIN-2144' 'PLAIN-2155' 'PLAIN-2166'
#  'PLAIN-2176' 'PLAIN-2186' 'PLAIN-2196' 'PLAIN-2208' 'PLAIN-2219'
#  'PLAIN-2229' 'PLAIN-2239' 'PLAIN-2249' 'PLAIN-2260' 'PLAIN-2270'
#  'PLAIN-2280' 'PLAIN-2290' 'PLAIN-2300' 'PLAIN-2310' 'PLAIN-2320'
#  'PLAIN-2331' 'PLAIN-2342' 'PLAIN-2353' 'PLAIN-2363' 'PLAIN-2374'
#  'PLAIN-2385' 'PLAIN-2395' 'PLAIN-2407' 'PLAIN-2429' 'PLAIN-2439'
#  'PLAIN-2449' 'PLAIN-2459' 'PLAIN-2469' 'PLAIN-2479' 'PLAIN-2489'
#  'PLAIN-2499' 'PLAIN-2509' 'PLAIN-2519' 'PLAIN-2529' 'PLAIN-2539'
#  'PLAIN-2549' 'PLAIN-2559' 'PLAIN-2569' 'PLAIN-2579' 'PLAIN-2589'
#  'PLAIN-2599' 'PLAIN-2609' 'PLAIN-2619' 'PLAIN-2629' 'PLAIN-2639'
#  'PLAIN-2649' 'PLAIN-2659' 'PLAIN-2669' 'PLAIN-2679' 'PLAIN-2689'
#  'PLAIN-2699' 'PLAIN-2709' 'PLAIN-2719' 'PLAIN-2729' 'PLAIN-2739'
#  'PLAIN-2749' 'PLAIN-2759' 'PLAIN-2769' 'PLAIN-2779' 'PLAIN-2789'
#  'PLAIN-2799' 'PLAIN-2809' 'PLAIN-2819' 'PLAIN-2829' 'PLAIN-2839'
#  'PLAIN-2849' 'PLAIN-2859' 'PLAIN-2869' 'PLAIN-2879' 'PLAIN-2889'
#  'PLAIN-2899' 'PLAIN-2909' 'PLAIN-2919' 'PLAIN-2929' 'PLAIN-2939'
#  'PLAIN-2949' 'PLAIN-2959' 'PLAIN-2969' 'PLAIN-2979' 'PLAIN-2990'
#  'PLAIN-3000' 'PLAIN-3013' 'PLAIN-3025' 'PLAIN-3036' 'PLAIN-3052'
#  'PLAIN-3062' 'PLAIN-3073' 'PLAIN-3084' 'PLAIN-3096' 'PLAIN-3114'
#  'PLAIN-3130' 'PLAIN-3140' 'PLAIN-3150' 'PLAIN-3160' 'PLAIN-3170'
#  'PLAIN-3180' 'PLAIN-3190' 'PLAIN-3200' 'PLAIN-3210' 'PLAIN-3220'
#  'PLAIN-3230' 'PLAIN-3240' 'PLAIN-3250' 'PLAIN-3260' 'PLAIN-3270'
#  'PLAIN-3280' 'PLAIN-3291' 'PLAIN-3301' 'PLAIN-3311' 'PLAIN-3321'
#  'PLAIN-3331' 'PLAIN-3341' 'PLAIN-3351' 'PLAIN-3361' 'PLAIN-3371'
#  'PLAIN-3381' 'PLAIN-3391' 'PLAIN-3401' 'PLAIN-3411' 'PLAIN-3421'
#  'PLAIN-3431' 'PLAIN-3441' 'PLAIN-3451' 'PLAIN-3461' 'PLAIN-3471'
#  'PLAIN-2' 'PLAIN-12' 'PLAIN-23' 'PLAIN-33' 'PLAIN-44' 'PLAIN-56'
#  'PLAIN-68' 'PLAIN-78' 'PLAIN-91' 'PLAIN-102' 'PLAIN-112' 'PLAIN-123'
#  'PLAIN-133' 'PLAIN-143' 'PLAIN-153' 'PLAIN-165' 'PLAIN-175' 'PLAIN-186'
#  'PLAIN-196' 'PLAIN-207' 'PLAIN-217' 'PLAIN-227' 'PLAIN-238' 'PLAIN-248'
#  'PLAIN-259' 'PLAIN-270' 'PLAIN-280' 'PLAIN-291' 'PLAIN-307' 'PLAIN-320'
#  'PLAIN-332' 'PLAIN-344' 'PLAIN-358' 'PLAIN-371' 'PLAIN-383' 'PLAIN-395'
#  'PLAIN-407' 'PLAIN-418' 'PLAIN-430' 'PLAIN-441' 'PLAIN-457' 'PLAIN-468'
#  'PLAIN-478' 'PLAIN-488' 'PLAIN-499' 'PLAIN-510' 'PLAIN-520' 'PLAIN-531'
#  'PLAIN-541' 'PLAIN-551' 'PLAIN-561' 'PLAIN-571' 'PLAIN-583' 'PLAIN-593'
#  'PLAIN-603' 'PLAIN-613' 'PLAIN-623' 'PLAIN-634' 'PLAIN-645' 'PLAIN-660'
#  'PLAIN-671' 'PLAIN-681' 'PLAIN-691' 'PLAIN-701' 'PLAIN-711' 'PLAIN-721'
#  'PLAIN-731' 'PLAIN-741' 'PLAIN-751' 'PLAIN-761' 'PLAIN-771' 'PLAIN-782'
#  'PLAIN-792' 'PLAIN-806' 'PLAIN-817' 'PLAIN-827' 'PLAIN-838' 'PLAIN-850'
#  'PLAIN-860' 'PLAIN-872' 'PLAIN-882' 'PLAIN-892' 'PLAIN-902' 'PLAIN-913'
#  'PLAIN-924' 'PLAIN-934' 'PLAIN-946' 'PLAIN-956' 'PLAIN-966' 'PLAIN-977'
#  'PLAIN-987' 'PLAIN-997' 'PLAIN-1008' 'PLAIN-1018' 'PLAIN-1028'
#  'PLAIN-1039' 'PLAIN-1050' 'PLAIN-1066' 'PLAIN-1078' 'PLAIN-1088'
#  'PLAIN-1098' 'PLAIN-1109' 'PLAIN-1119' 'PLAIN-1130' 'PLAIN-1141'
#  'PLAIN-1151' 'PLAIN-1161' 'PLAIN-1172' 'PLAIN-1183' 'PLAIN-1193'
#  'PLAIN-1203' 'PLAIN-1214' 'PLAIN-1225' 'PLAIN-1236' 'PLAIN-1249'
#  'PLAIN-1262' 'PLAIN-1275' 'PLAIN-1288' 'PLAIN-1299' 'PLAIN-1309'
#  'PLAIN-1320' 'PLAIN-1331' 'PLAIN-1342' 'PLAIN-1353' 'PLAIN-1363'
#  'PLAIN-1374' 'PLAIN-1387' 'PLAIN-1398' 'PLAIN-1409' 'PLAIN-1419'
#  'PLAIN-1429' 'PLAIN-1441' 'PLAIN-1453' 'PLAIN-1463' 'PLAIN-1473'
#  'PLAIN-1485' 'PLAIN-1496' 'PLAIN-1506' 'PLAIN-1516' 'PLAIN-1527'
#  'PLAIN-1537' 'PLAIN-1547' 'PLAIN-1557' 'PLAIN-1568' 'PLAIN-1579'
#  'PLAIN-1590' 'PLAIN-1601' 'PLAIN-1611' 'PLAIN-1621' 'PLAIN-1635'
#  'PLAIN-1645' 'PLAIN-1656' 'PLAIN-1667' 'PLAIN-1679' 'PLAIN-1690'
#  'PLAIN-1700' 'PLAIN-1710' 'PLAIN-1721' 'PLAIN-1731' 'PLAIN-1741'
#  'PLAIN-1752' 'PLAIN-1762' 'PLAIN-1772' 'PLAIN-1784' 'PLAIN-1794'
#  'PLAIN-1805' 'PLAIN-1817' 'PLAIN-1827' 'PLAIN-1837' 'PLAIN-1847'
#  'PLAIN-1857' 'PLAIN-1867' 'PLAIN-1877' 'PLAIN-1887' 'PLAIN-1897'
#  'PLAIN-1909' 'PLAIN-1919' 'PLAIN-1929' 'PLAIN-1940' 'PLAIN-1950'
#  'PLAIN-1962' 'PLAIN-1972' 'PLAIN-1983' 'PLAIN-1995' 'PLAIN-2009'
#  'PLAIN-2019' 'PLAIN-2030' 'PLAIN-2040' 'PLAIN-2051' 'PLAIN-2061'
#  'PLAIN-2071' 'PLAIN-2081' 'PLAIN-2092' 'PLAIN-2102' 'PLAIN-2113'
#  'PLAIN-2124' 'PLAIN-2134' 'PLAIN-2145' 'PLAIN-2156' 'PLAIN-2167'
#  'PLAIN-2177' 'PLAIN-2187' 'PLAIN-2197' 'PLAIN-2209' 'PLAIN-2220'
#  'PLAIN-2230' 'PLAIN-2240' 'PLAIN-2250' 'PLAIN-2261' 'PLAIN-2271'
#  'PLAIN-2281' 'PLAIN-2291' 'PLAIN-2301' 'PLAIN-2311' 'PLAIN-2321'
#  'PLAIN-2332' 'PLAIN-2343' 'PLAIN-2354' 'PLAIN-2364' 'PLAIN-2375'
#  'PLAIN-2386' 'PLAIN-2396' 'PLAIN-2408' 'PLAIN-2430' 'PLAIN-2440'
#  'PLAIN-2450' 'PLAIN-2460' 'PLAIN-2470' 'PLAIN-2480' 'PLAIN-2490'
#  'PLAIN-2500' 'PLAIN-2510' 'PLAIN-2520' 'PLAIN-2530' 'PLAIN-2540'
#  'PLAIN-2550' 'PLAIN-2560' 'PLAIN-2570' 'PLAIN-2580' 'PLAIN-2590'
#  'PLAIN-2600' 'PLAIN-2610' 'PLAIN-2620' 'PLAIN-2630' 'PLAIN-2640'
#  'PLAIN-2650' 'PLAIN-2660' 'PLAIN-2670' 'PLAIN-2680' 'PLAIN-2690'
#  'PLAIN-2700' 'PLAIN-2710' 'PLAIN-2720' 'PLAIN-2730' 'PLAIN-2740'
#  'PLAIN-2750' 'PLAIN-2760' 'PLAIN-2770' 'PLAIN-2780' 'PLAIN-2790'
#  'PLAIN-2800' 'PLAIN-2810' 'PLAIN-2820' 'PLAIN-2830' 'PLAIN-2840'
#  'PLAIN-2850' 'PLAIN-2860' 'PLAIN-2870' 'PLAIN-2880' 'PLAIN-2890'
#  'PLAIN-2900' 'PLAIN-2910' 'PLAIN-2920' 'PLAIN-2930' 'PLAIN-2940'
#  'PLAIN-2950' 'PLAIN-2960' 'PLAIN-2970' 'PLAIN-2981' 'PLAIN-2991'
#  'PLAIN-3001' 'PLAIN-3014' 'PLAIN-3026' 'PLAIN-3037' 'PLAIN-3053'
#  'PLAIN-3063' 'PLAIN-3074' 'PLAIN-3085' 'PLAIN-3097' 'PLAIN-3116'
#  'PLAIN-3131' 'PLAIN-3141' 'PLAIN-3151' 'PLAIN-3161' 'PLAIN-3171'
#  'PLAIN-3181' 'PLAIN-3191' 'PLAIN-3201' 'PLAIN-3211' 'PLAIN-3221'
#  'PLAIN-3231' 'PLAIN-3241' 'PLAIN-3251' 'PLAIN-3261' 'PLAIN-3271'
#  'PLAIN-3281' 'PLAIN-3292' 'PLAIN-3302' 'PLAIN-3312' 'PLAIN-3322'
#  'PLAIN-3332' 'PLAIN-3342' 'PLAIN-3352' 'PLAIN-3362' 'PLAIN-3372'
#  'PLAIN-3382' 'PLAIN-3392' 'PLAIN-3402' 'PLAIN-3412' 'PLAIN-3422'
#  'PLAIN-3432' 'PLAIN-3442' 'PLAIN-3452' 'PLAIN-3462' 'PLAIN-3472']
# Number of missing queries:  30409
# Number of rows in qrels:  169759

# %%
for index, row in train_qrels.iterrows():
    print(f"Processing row {index}", end='\r')
    query_id = row['QUERY_ID']
    doc_id = row['DOC_ID']
    relevance_label = row['RELEVANCE_LEVEL']
    # print(f"Query ID: {query_id}, Doc ID: {doc_id}, Relevance: {relevance_label}")
    # Check if the query ID is found within the queries DataFrame
    query_indices = queries[queries['QUERY_ID'] == query_id].index.tolist()
    if query_indices:  # This checks if the list is non-empty
        query_vector = query_vectors[query_indices[0]]
        if doc_id in doc_id_to_index:
            doc_vector = doc_vectors[doc_id_to_index[doc_id]]
            # Calculate features and append to training data
            features = cosine_similarity(query_vector, doc_vector).flatten()
            X_train.append(features)
            Y_train.append(relevance_label)
        # print(f"Query ID {query_id} found in training queries")
    else:
        print(f"Query ID {query_id} not found in training queries")
# Out:
# Processing row 153938

# %%
# Load test queries
test_query_columns = ['QUERY_ID', 'QUERY_TEXT']
test_queries = pd.read_csv('./nfcorpus/test.titles.queries', sep='\t', names=test_query_columns, header=None)

# Vectorize test queries using the already fitted vectorizer
test_query_vectors = vectorizer.transform(test_queries['QUERY_TEXT'])

# Filter qrels to only include test query IDs
test_qrels = qrels[qrels['QUERY_ID'].isin(test_queries['QUERY_ID'])]
print(len(test_qrels))

# Initialize lists for test data
X_test = []
Y_test = []

# Iterate over each entry in the test relevance judgments
for index, row in test_qrels.iterrows():
    print(f"Processing row {index}", end='\r')
    query_id = row['QUERY_ID']
    doc_id = row['DOC_ID']
    relevance_label = row['RELEVANCE_LEVEL']
        
    # Find the query index and corresponding vector
    query_indices = test_queries[test_queries['QUERY_ID'] == query_id].index.tolist()
    if query_indices:  # This checks if the list is non-empty
        query_vector = test_query_vectors[query_indices[0]]
        if doc_id in doc_id_to_index:
            doc_vector = doc_vectors[doc_id_to_index[doc_id]]
            
            # Calculate features
            features = cosine_similarity(query_vector, doc_vector).flatten()
            X_test.append(features)
            Y_test.append(relevance_label)
    else:
        print(f"Test Query ID {query_id} not found in test queries")
# Out:
# 15820
# Processing row 169758

# %%
# val set
val_query_columns = ['QUERY_ID', 'QUERY_TEXT']
val_queries = pd.read_csv('./nfcorpus/dev.titles.queries', sep='\t', names=val_query_columns, header=None)

# Vectorize test queries using the already fitted vectorizer
val_query_vectors = vectorizer.transform(val_queries['QUERY_TEXT'])

# Filter qrels to only include test query IDs
val_qrels = qrels[qrels['QUERY_ID'].isin(val_queries['QUERY_ID'])]
print(len(val_qrels))

# Initialize lists for test data
X_val = []
Y_val = []

# Iterate over each entry in the test relevance judgments
for index, row in val_qrels.iterrows():
    print(f"Processing row {index}", end='\r')
    query_id = row['QUERY_ID']
    doc_id = row['DOC_ID']
    relevance_label = row['RELEVANCE_LEVEL']
        
    # Find the query index and corresponding vector
    query_indices = val_queries[val_queries['QUERY_ID'] == query_id].index.tolist()
    if query_indices:  # This checks if the list is non-empty
        query_vector = val_query_vectors[query_indices[0]]
        if doc_id in doc_id_to_index:
            doc_vector = doc_vectors[doc_id_to_index[doc_id]]
            
            # Calculate features
            features = cosine_similarity(query_vector, doc_vector).flatten()
            X_val.append(features)
            Y_val.append(relevance_label)
    else:
        print(f"Val Query ID {query_id} not found in val queries")
# Out:
# 14589
# Processing row 14588

# %%
# Convert lists to arrays if needed, for compatibility with scikit-learn
import numpy as np
X_train = np.array(X_train)
Y_train = np.array(Y_train)

from sklearn.ensemble import RandomForestClassifier

# Train a simple model
model = RandomForestClassifier(n_estimators=100)
model.fit(X_train, Y_train)
# Out:
# RandomForestClassifier()

# %%
# NDCG evaluation
from sklearn.metrics import ndcg_score

# Predict on the test set
Y_pred = model.predict(X_test)

# Calculate NDCG
ndcg = ndcg_score([Y_test], [Y_pred], k=10)
print(f"NDCG@10: {ndcg}")
# Out:
# NDCG@10: 0.6732186732186731
